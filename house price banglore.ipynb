# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Rifa Rahman\Desktop\Entri\power bi\bengaluru_house_prices.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %% [markdown]
# # basic data cleaning

# %%
#checking null values

df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
#removing null values
df.dropna()
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#checking and removing duplicate values

df.duplicated().sum()
# Out:
# 529

# %%
df1=df.drop_duplicates()
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
#tsking only huses which are ready to move
ready_to_move = df[df['availability'] == 'Ready To Move']
ready_to_move
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 2            Built-up  Area  Ready To Move            Uttarahalli      3 BHK
# 3      Super built-up  Area  Ready To Move     Lingadheeranahalli      3 BHK
# 4      Super built-up  Area  Ready To Move               Kothanur      2 BHK
# 5      Super built-up  Area  Ready To Move             Whitefield      2 BHK
# ...                     ...            ...                    ...        ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
# ...

# %%
# converting sqrfeet to number
def square_feet_to_square_meters(square_feet):
    square_meters=square_feet*0.092903
    return square_meters

# %%
ready_to_move.head()
# Out:
#               area_type   availability            location       size  \
# 1            Plot  Area  Ready To Move    Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move         Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move  Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move            Kothanur      2 BHK
# 5  Super built-up  Area  Ready To Move          Whitefield      2 BHK
#
#    society total_sqft  bath  balcony  price
# 1  Theanmp       2600   5.0      3.0  120.0
# 2      NaN       1440   2.0      3.0   62.0
# 3  Soiewre       1521   3.0      1.0   95.0
# 4      NaN       1200   2.0      1.0   51.0
# 5  DuenaTa       1170   2.0      1.0   38.0

# %% [markdown]
# # visualization

# %%
#Bar plot
area=ready_to_move['area_type'].head(10)
price=ready_to_move['price'].head(10)
plt.xlabel('areatype')
plt.ylabel('price')
plt.bar(area,price)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv(r"C:\Users\Rifa Rahman\Desktop\Entri\power bi\bengaluru_house_prices.csv")

# Visualizing feature relationships using a pair plot
sns.pairplot(ready_to_move, x_vars=['total_sqft', 'bath', 'balcony'], y_vars=['price'], height=5, aspect=0.6)
plt.title("Feature Relationships")
plt.show()
# Out:
# C:\Users\Rifa Rahman\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Rifa Rahman\Desktop\Entri\power bi\bengaluru_house_prices.csv")


sns.boxplot(x='price', data=ready_to_move)
plt.title("Distribution of Prices")
plt.xlabel("Price")
plt.show()

# %%
sns.histplot(ready_to_move['price'], kde=False)

# Set the x-axis limits to focus on the range between 0 and 1000
plt.xlim(0, 400)

plt.title("Distribution of Prices")
plt.show()
